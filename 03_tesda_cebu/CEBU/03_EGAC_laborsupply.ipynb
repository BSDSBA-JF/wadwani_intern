# %%
import pandas as pd

# %% [markdown]
# # CEBU - Labor Supply 2024

# %% [markdown]
# ### Loading Data and Qualifications

# %%
# Load the Excel file
file_path = "data/TESDA 2024 EGAC.xlsx"  # change to your actual path
xls = pd.ExcelFile(file_path)

# Load a specific sheet
df_eg = pd.read_excel(xls, sheet_name='EG 2024')
df_ac = pd.read_excel(xls, sheet_name='AC 2024', header = 1)

# %%
unique_quals = df_eg['Qualification'].dropna().unique()
print(unique_quals)
# Out:
# ['2D Animation NC III' '3D Animation NC III'
#  'Agricultural Crops Production NC I'
#  'Agricultural Crops Production NC II'
#  'Agricultural Crops Production NC III'
#  'Agricultural Machinery Operation NC II' 'Agroentrepreneurship NC II'
#  'Agroentrepreneurship NC III' 'Animal Production (Poultry-Chicken) NC II'
#  'Animal Production (Ruminants) NC II' 'Animal Production (Swine) NC II'
#  'Animation NC II' 'Aquaculture NC II'
#  'Artificial Insemination (Swine) NC II'
#  'Automotive Body Painting/Finishing NC II'
#  'Automotive Body Repairing NC II'
#  'Automotive Servicing (Chassis Repair) NC II'
#  'Automotive Servicing (Electrical Repair) NC II'
#  'Automotive Servicing (Engine Repair) NC II' 'Automotive Servicing NC I'
#  'Automotive Servicing NC II' 'Automotive Servicing NC III'
#  'Automotive Servicing NC IV' 'Automotive Wiring Harness Assembly NC II'
#  'Bamboo Production NC II' 'Barangay Health Services NC II'
#  'Barbering NC II' 'Barista NC II' 'Bartending NC II'
#  'Beauty Care (Nail Care) Services NC II'
#  'Beauty Care Services (Nail Care) NC II'
#  'Biomedical Equipment Servicing NC II' 'Bookkeeping NC III'
#  'Bread and Pastry Production NC II' 'Caregiving (Elderly) NC II'
#  'Caregiving (Newborn to Pre-Schooler) NC II' 'Caregiving NC II'
#  'Carpentry NC II' 'Carpentry NC III' 'CNC Lathe Machine Operation NC II'
#  'CNC Lathe Machine Operation NC III'
#  'CNC Milling Machine Operation NC II' 'Commercial Cooking NC III'
#  'Commercial Cooking NC IV' 'Computer Systems Servicing NC II'
#  'Construction Painting NC II' 'Contact Center Services NC II'
#  'Cookery NC II' 'Customer Services NC II' 'Dental Hygiene NC IV'
#  'Dental Laboratory Technology Services (Fixed Dentures/Restorations) NC II'
#  'Dental Laboratory Technology Services (Removable Dentures/Appliances) NC II'
#  'Dental Laboratory Technology Services NC I' 'Dental Technology NC IV'
#  'Domestic Work NC II' 'Dressmaking NC II'
#  'Driving (Articulated Vehicle) NC III'
#  'Driving (Passenger Bus/Straight Truck) NC III' 'Driving NC II'
#  'Drying and Milling Plant Servicing NC III'
#  'Electric Power Distribution Line Construction NC II'
#  'Electrical Installation and Maintenance NC II'
#  'Electrical Installation and Maintenance NC III'
#  'Electrical Installation and Maintenance NC IV'
#  'Electronic Products Assembly and Servicing NC II'
#  'Emergency Medical Services NC II' 'Emergency Medical Services NC III'
#  'Events Management Services NC III' 'Flux-Cored Arc Welding (FCAW) NC II'
#  'Food and Beverage Services NC II' 'Food and Beverage Services NC III'
#  'Food Processing NC II' 'Front Office Services NC II'
#  'Game Programming NC III' 'Gas Metal Arc Welding (GMAW) NC I'
#  'Gas Metal Arc Welding (GMAW) NC II'
#  'Gas Metal Arc Welding (GMAW) NC III'
#  'Gas Tungsten Arc Welding (GTAW) NC II' 'Gas Welding NC II'
#  'Grains Production NC II' 'Hairdressing NC II'
#  'Health Care Services NC II'
#  'Heavy Equipment Operation (Backhoe Loader) NC II'
#  'Heavy Equipment Operation (Bulldozer) NC II'
#  'Heavy Equipment Operation (Forklift) NC II'
#  'Heavy Equipment Operation (Hydraulic Excavator) NC II'
#  'Heavy Equipment Operation (Motor Grader) NC II'
#  'Heavy Equipment Operation (Rigid On-Highway Dump Truck) NC II'
#  'Heavy Equipment Operation (Road Roller) NC II'
#  'Heavy Equipment Operation (Wheel Loader) NC II'
#  'Heavy Equipment Servicing (Mechanical) NC II'
#  'Hilot (Wellness Massage) NC II' 'Horticulture NC III'
#  'Housekeeping NC II' 'Housekeeping NC III' 'Illustration NC II'
#  'Instrumentation and Control Servicing NC II'
#  'Landscape Installation and Maintenance (Softscape) NC II'
#  'Local Guiding Services NC II' 'Machining NC I' 'Machining NC II'
#  'Masonry NC I' 'Masonry NC II' 'Massage Therapy NC II'
#  'Mechanical Drafting NC I' 'Mechatronics Servicing NC II'
#  'Mechatronics Servicing NC III' 'Mechatronics Servicing NC IV'
#  'Medical Transcription NC II' 'Microfinance Technology NC II'
#  'Motorcycle/Small Engine Servicing NC II'
#  'Organic Agriculture Production NC II'
#  'Pest Management (Vegetables) NC II' 'Pharmacy Services NC III'
#  'Photography NC II' 'Pipefitting (Metallic) NC II' 'Plumbing NC I'
#  'Plumbing NC II' 'Plumbing NC III' 'Programming (Java) NC III'
#  'PV Systems Installation NC II' 'PV Systems Servicing NC III'
#  'RAC Servicing (DomRAC) NC II' 'Reinforcing Steel Works NC II'
#  'Rice Machinery Operations NC II' 'Rigging NC I'
#  'Rubber Production NC II'
#  'Scaffolding Works (Supported Type Scaffold) NC II'
#  'Seaweed Production NC II' 'Security Services NC I'
#  'Security Services NC II' 'Shielded Metal Arc Welding (SMAW) NC I'
#  'Shielded Metal Arc Welding (SMAW) NC II'
#  'Shielded Metal Arc Welding (SMAW) NC III'
#  'Shielded Metal Arc Welding (SMAW) NC IV'
#  "Ships' Catering (Ships' Cooks) NC III" "Ship's Catering Services NC I"
#  'Slaughtering Operations (Large Animal) NC II'
#  'Slaughtering Operations (Swine) NC II'
#  'System Formworks Installation NC II' 'Tailoring NC II'
#  'Technical Drafting NC II'
#  'Telecom OSP Installation (Fiber Optic Cable) NC II' 'Tile Setting NC II'
#  'Tourism Promotion Services NC II' 'Trainers Methodology Level I'
#  'Trainers Methodology Level II' 'Travel Services NC II'
#  'Visual Graphic Design NC III' 'Warehousing Services NC II'
#  'Web Development NC III']

# %%
tourism_NC_list = [
    "Tour Guiding Services NC II",
    "Tourism Promotion Services NC II",
    "Front Office Services NC II",
    "Housekeeping NC II",
    "Bartending NC II",
    "Barista NC II",
    "Food and Beverage Services NC II",
    "Cookery NC II",
    "Bread and Pastry Production NC II",
    "Events Management Services NC III"
]

# %% [markdown]
# ## Total Enrolled (E)

# %%
# Filter rows for Region VII - Central Visayas and tourism/hospitality qualifications
region_vii_cebu_tourism = df_eg[
    (df_eg["Region Name"] == "Region VII - Central Visayas") &
    (df_eg["Province Name"] == "Cebu") &
    (df_eg["Qualification"].isin(tourism_NC_list))
]

total_enrolled = region_vii_cebu_tourism["Enrolled"].sum()

print("Total Enrolled (Tourism & Hospitality, Region VII - Central Visayas):", total_enrolled)
# Out:
# Total Enrolled (Tourism & Hospitality, Region VII - Central Visayas): 10807

# %% [markdown]
# ## Total Graduated (G)

# %%
# Filter rows for Region VII - Central Visayas and tourism/hospitality qualifications
region_vii_cebu_tourism = df_eg[
    (df_eg["Region Name"] == "Region VII - Central Visayas") &
    (df_eg["Province Name"] == "Cebu") &
    (df_eg["Qualification"].isin(tourism_NC_list))
]

total_graduated = region_vii_cebu_tourism["Graduates"].sum()

print("Total Graduates (Tourism & Hospitality, Region VII - Central Visayas):", total_graduated)
# Out:
# Total Graduates (Tourism & Hospitality, Region VII - Central Visayas): 11045

# %% [markdown]
# ### Loading Data and Qualifications

# %%
unique_quals = df_ac['Qualification'].dropna().unique()
print(unique_quals)
# Out:
# ['Bartending NC II' 'Bread and Pastry Production NC II' 'Cookery NC II'
#  'Food and Beverage Services NC II' 'Hilot (Wellness Massage) NC II'
#  'Driving NC II' 'Housekeeping NC II' 'Masonry NC II'
#  'Organic Agriculture Production NC II'
#  'Shielded Metal Arc Welding (SMAW) NC I'
#  'Shielded Metal Arc Welding (SMAW) NC II' 'Trainers Methodology Leve I'
#  'Visual Graphic Design NC III' 'Caregiving NC II' 'Carpentry NC II'
#  'Dressmaking NC II' 'Electronic Products Assembly and Servicing NC II'
#  'Gas Metal Arc Welding (GMAW) NC II' 'Health Care Services NC II'
#  'Heavy Equipment Operation (Forklift) NC II' 'Tile Setting NC II'
#  'Driving (Articulated Vehicle) NC III'
#  'Driving (Passenger Bus/Straight Truck) NC III'
#  'Heavy Equipment Operation (Hydraulic Excavator) NC II'
#  'Heavy Equipment Operation (Rigid On-Highway Dump Truck) NC II'
#  'Agricultural Crops Production NC I'
#  'Agricultural Crops Production NC II'
#  'Agricultural Crops Production NC III' 'Animal Production (Swine) NC II'
#  'Automotive Servicing NC I' 'Barangay Health Services NC II'
#  'Computer Systems Servicing NC II' 'Front Office Services NC II'
#  'Electrical Installation and Maintenance NC II' 'Barbering NC II'
#  'Bookkeeping NC III' 'Events Management Services NC III'
#  'Food and Beverage Services NC III'
#  'Slaughtering Operations (Swine) NC II'
#  'Electric Power Distribution Line Construction NC II'
#  'Heavy Equipment Operation (Truck Mounted Crane) NC II' 'Barista NC II'
#  'PV Systems Installation NC II'
#  'Automotive Servicing (Chassis Repair) NC II'
#  'Automotive Servicing (Engine Repair) NC II'
#  'Heavy Equipment Operation (Backhoe Loader) NC II'
#  'Heavy Equipment Operation (Wheel Loader) NC II'
#  'Motorcycle/Small Engine Servicing NC II' 'Agroentrepreneurship NC II'
#  'Commercial Cooking NC III' 'Food Processing NC II'
#  'Tourism Promotion Services NC II' 'Biomedical Equipment Servicing NC II'
#  'Web Development NC III' 'Massage Therapy NC II'
#  'Bamboo Production NC II' 'Caregiving (Elderly) NC II'
#  'Animal Production (Ruminants) NC II' 'Rice Machinery Operations NC II'
#  'Carpentry NC III'
#  'Commercial Air-conditioning Installation and Servicing NC III'
#  'Domestic Work NC II' 'Masonry NC III' 'RAC Servicing (DomRAC) NC II'
#  'Automotive Servicing (Electrical Repair) NC II'
#  'Heavy Equipment Operation (Bulldozer) NC II'
#  'Heavy Equipment Operation (Road Roller) NC II'
#  'Scaffolding Works (Supported Type Scaffold) NC II' 'Housekeeping NC III'
#  'Agroentrepreneurship NC III'
#  'Heavy Equipment Servicing (Mechanical) NC II' 'Plumbing NC II'
#  'Beauty Care (Skin Care) Services NC II' 'Hairdressing NC II'
#  'Electrical Installation and Maintenance NC III'
#  'Gas Tungsten Arc Welding (GTAW) NC II' 'Masonry NC I'
#  "Ships' Catering (Ships' Cooks) NC III" "Ship's Catering Services NC I"
#  'Construction Painting NC II' 'Pharmacy Services NC III'
#  'Beauty Care (Nail Care) Services NC II' 'Tailoring NC II'
#  'Technical Drafting NC II'
#  'Heavy Equipment Operation (Transit Mixer) NC II'
#  'Pest Management (Vegetables) NC II'
#  'Animal Health Care and Management NC III'
#  'Animal Production (Poultry-Chicken) NC II' 'Grains Production NC II'
#  'Milking Operation NC II'
#  'Landscape Installation and Maintenance (Softscape) NC II'
#  'Heavy Equipment Operation (Motor Grader) NC II'
#  'Automotive Servicing NC IV' 'PV Systems Servicing NC III'
#  'Customer Services NC II' 'Reinforcing Steel Works NC II'
#  'Transport RAC Servicing NC II' 'Security Services NC II' 'Rigging NC I'
#  'Horticulture NC III' 'Shielded Metal Arc Welding (SMAW) NC III'
#  'Fish Capture NC II' 'Instrumentation and Control Servicing NC II'
#  'Instrumentation and Control Servicing NC III' 'Travel Services NC II'
#  'Pipefitting (Metallic) NC II'
#  'Heavy Equipment Operation (Crawler Crane) NC III'
#  'Heavy Equipment Operation (Overhead and Gantry Crane) NC III'
#  'Heavy Equipment Operation (Rough Terrain Crane) NC III'
#  'Heavy Equipment Operation (Truck Mounted Crane) NC III'
#  'Flux-Cored Arc Welding (FCAW) NC II'
#  'Slaughtering Operations (Large Animal) NC II'
#  'Electrical Installation and Maintenance NC IV' 'Machining NC I'
#  'Machining NC II' 'Food and Beverage Services NC IV' 'Housekeeping NC IV'
#  'Microfinance Technology NC II'
#  'Mobile Phones and Handheld Gadgets Servicing NC III'
#  'Front Office Services NC III' 'Front Office Services NC IV'
#  'Security Services NC I' 'Medical Transcription NC II'
#  'Emergency Medical Services NC II' 'Emergency Medical Services NC III'
#  'Real Estate Services NC II' 'Agroentrepreneurship NC IV'
#  'Automotive Wiring Harness Assembly NC II' 'Animation NC II'
#  'Hairdressing NC III' 'Caregiving (Newborn to Pre-Schooler) NC II'
#  'Plumbing NC I' 'Gas Metal Arc Welding (GMAW) NC I'
#  'Mechatronics Servicing NC II' 'Shielded Metal Arc Welding (SMAW) NC IV'
#  'Mechanical Drafting NC I' '2D Animation NC III'
#  'CNC Milling Machine Operation NC II'
#  'Telecom OSP Installation (Fiber Optic Cable) NC II'
#  'Automotive Servicing NC II'
#  ' Caregiving (Clients with Special Needs) NC II'
#  'Mechatronics Servicing NC III' 'Trainers Methodology Level II'
#  'RAC Servicing (PACU-CRE) NC III' 'Automotive Body Repairing NC II'
#  'Automotive Painting NC II' 'Automotive Servicing NC III'
#  'Food Processing NC I' 'Fashion Design (Apparel) NC III'
#  'Commercial Refrigeration Installation and Servicing NC III'
#  'Local Guiding Services NC II' 'Commercial Cooking NC IV'
#  'Food Production (Professional Cookery) NC III'
#  'Heavy Equipment Operation (Rigid Off-Highway Dump Truck) NC II'
#  'Public Employment Services NC IV' 'System Formworks Installation NC II'
#  'CNC Lathe Machine Operation NC II'
#  ' Heavy Equipment Operation (Tower Crane) NC III' 'Photography NC II'
#  'Warehousing Services NC II' 'Artificial Insemination (Swine) NC II'
#  'Beauty Care NC II' 'Aquaculture NC II' 'Seaweed Production NC II'
#  'Bamboo Processing (Engineered Bamboo) NC II'
#  'Beauty Care Services (Nail Care) NC II'
#  'Tour Packaging (FIT Ad Hoc Domestic) Services NC II'
#  'Game Programming NC III' 'Illustration NC II'
#  'Heavy Equipment Operation (Crawler Crane) NC II'
#  'Heavy Equipment Operation (Gantry Crane) NC II'
#  'Heavy Equipment Operation (Rough Terrain Crane) NC II'
#  'Heavy Equipment Operation (Tower Crane) NC II'
#  'Dental Laboratory Technology Services (Fixed Dentures/Restorations) NC II'
#  'Dental Laboratory Technology Services (Removable Dentures/Appliances) NC II'
#  'Mechatronics Servicing NC IV' 'Plumbing NC III' '3D Animation NC III'
#  'Electric Power Distribution Operation and Maintenance NC III'
#  'Handloom Weaving (Upright) NC II' 'Rubber Production NC II'
#  'Gas Metal Arc Welding (GMAW) NC III'
#  'Agricultural Machinery Servicing (4-Wheel Tractor) NC III'
#  'Artificial Insemination (Large Ruminants) NC II'
#  'Beauty Care (Nail Enhancement Technology) Services NC III'
#  'Community Nutrition Services NC II'
#  'Food Production (Professional Cookery) NC IV' 'Garbage Collection NC I'
#  'Heavy Equipment Operation (Concrete Pump) NC II'
#  'Land-Based Transport Mobile Air-conditioning (MAC) Servicing NC II'
#  'Manual Metal Arc Welding (MMAW) NC I'
#  'Microinsurance Services (Mutual Benefit) NC II'
#  'Multimodal Transport Operation and Logistics (Seafreight Import) Services NC III'
#  'Multimodal Transport Operation and Logistics (Seafreight Import) Services NC II'
#  'Multimodal Transport Operation and Logistics (Seafreight Import) Services NC IV'
#  'Sanitary Landfill Operations NC II'
#  'Sanitary Landfill Operations NC III']

# %%
tourism_NC_list = [
    "Front Office Services NC II",
    "Tourism Promotion Services NC II",
    "Tour Guiding Services NC II",
    "Events Management Services NC III",
    "Food and Beverage Services NC II",
    "Bartending NC II",
    "Cookery NC II",
    "Commercial Cooking NC III",
    "Commercial Cooking NC IV",
    "Bread and Pastry Production NC II",
    "Housekeeping NC II",
    "Housekeeping NC III",
    "Housekeeping NC IV",
    "Barista NC II",
    "Travel Services NC II",
    "Tour Packaging (FIT Ad Hoc Domestic) Services NC II",
    "Food Production (Professional Cookery) NC III",
    "Food Production (Professional Cookery) NC IV"
]

# %% [markdown]
# ## Total Assessed (A)

# %%
# Filter rows for Region VII - Central Visayas and tourism/hospitality qualifications
region_vii_cebu_tourism = df_ac[
    (df_ac["Region"] == "Region VII - Central Visayas") &
    (df_ac["Province"] == "Cebu") &
    (df_ac["Qualification"].isin(tourism_NC_list))
]

total_assessed = region_vii_cebu_tourism["Assessed"].sum()

print("Total Assessed (Tourism & Hospitality, Region VII - Central Visayas):", total_assessed)
# Out:
# Total Assessed (Tourism & Hospitality, Region VII - Central Visayas): 16999

# %% [markdown]
# ## Total Certified (C)

# %%
# Filter rows for Region VII - Central Visayas and tourism/hospitality qualifications
region_vii_cebu_tourism = df_ac[
    (df_ac["Region"] == "Region VII - Central Visayas") &
    (df_ac["Province"] == "Cebu") &
    (df_ac["Qualification"].isin(tourism_NC_list))
]

total_certified = region_vii_cebu_tourism["Certified"].sum()

print("Total Certified (Tourism & Hospitality, Region VII - Central Visayas):", total_certified)
# Out:
# Total Certified (Tourism & Hospitality, Region VII - Central Visayas): 16822

# %% [markdown]
# # CEBU - Labor Supply 2025

# %% [markdown]
# ### Loading Data and Qualifications

# %% [markdown]
# loading the file

# %%
file_path = "data/EG 2025.csv"
df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 file_path = "data/EG 2025.csv"
# ----> 2 df = pd.read_csv(file_path)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# entries under column "Region Name"

# %%
# Get unique region names
unique_regions = df["Region Name"].dropna().unique()

# Print or save them
print(unique_regions)
# Out:
# ['Region I - Ilocos' 'National Capital Region (NCR)'
#  'Region X - Northern Mindanao' 'Region VII - Central Visayas'
#  'Cordillera Administrative Region (CAR)' 'Region V - Bicol'
#  'Region VI - Western Visayas' 'Region VIII - Eastern Visayas'
#  'Region III - Central Luzon' 'Region II - Cagayan Valley'
#  'Region IVA - CALABARZON' 'Region IVB - MIMAROPA'
#  'Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)'
#  'Region XI - Davao' 'Region IX - Zamboanga Peninsula'
#  'Region XII - SOCCSKSARGEN' 'Region XIII - CARAGA'
#  'Autonomous Region in Muslim Mindanao (ARMM)']

# %%
# Get unique qualifications
unique_qualifications = df["Qualification"].dropna().unique()

# Print the results
print(unique_qualifications)
# Out:
# ['Caregiving NC II' 'Computer Systems Servicing NC II'
#  'Automotive Servicing NC I' 'Barista NC II'
#  'Bread and Pastry Production NC II' 'Cookery NC II'
#  'Electrical Installation and Maintenance NC II'
#  'Food and Beverage Services NC II'
#  'Shielded Metal Arc Welding (SMAW) NC II'
#  "Ships' Catering (Ships' Cooks) NC III" "Ship's Catering Services NC I"
#  'Heavy Equipment Operation (Backhoe Loader) NC II' 'Bookkeeping NC III'
#  'Hilot (Wellness Massage) NC II' 'Tile Setting NC II'
#  'Organic Agriculture Production NC II' 'Driving NC II'
#  'Rice Machinery Operations NC II' 'Dressmaking NC II'
#  'Electronic Products Assembly and Servicing NC II'
#  'Shielded Metal Arc Welding (SMAW) NC I'
#  'Events Management Services NC III' 'Caregiving (Elderly) NC II'
#  'Trainers Methodology Level I' 'Domestic Work NC II'
#  'Heavy Equipment Operation (Motor Grader) NC II' 'Housekeeping NC II'
#  'Bartending NC II' 'Contact Center Services NC II'
#  'Electrical Installation and Maintenance NC III'
#  'Mechatronics Servicing NC II' 'Agricultural Crops Production NC II'
#  'Masonry NC II' 'Gas Tungsten Arc Welding (GTAW) NC II'
#  'Shielded Metal Arc Welding (SMAW) NC III'
#  'Driving (Passenger Bus/Straight Truck) NC III' 'Carpentry NC II'
#  'Heavy Equipment Operation (Forklift) NC II'
#  'Heavy Equipment Operation (Hydraulic Excavator) NC II' 'Masonry NC I'
#  'Agroentrepreneurship NC II'
#  'Commercial Air-conditioning Installation and Servicing NC III'
#  'Telecom OSP Installation (Fiber Optic Cable) NC II'
#  'Security Services NC II' 'Agricultural Crops Production NC I'
#  'Health Care Services NC II' 'Grains Production NC II'
#  'Landscape Installation and Maintenance (Softscape) NC II'
#  'Plumbing NC II' 'Scaffolding Works (Supported Type Scaffold) NC II'
#  ' Caregiving (Clients with Special Needs) NC II'
#  'Emergency Medical Services NC II' 'Reinforcing Steel Works NC II'
#  'Technical Drafting NC II' 'Visual Graphic Design NC III'
#  'Tourism Promotion Services NC II' 'Pipefitting (Metallic) NC II'
#  'Programming (Java) NC III' 'Animal Production (Poultry-Chicken) NC II'
#  'Animal Production (Swine) NC II' 'Horticulture NC III'
#  'Massage Therapy NC II' 'Heavy Equipment Operation (Wheel Loader) NC II'
#  'Bamboo Production NC II' 'Heavy Equipment Operation (Bulldozer) NC II'
#  'Beauty Care Services (Nail Care) NC II' 'Front Office Services NC II'
#  'Warehousing Services NC II' 'Commercial Cooking NC III'
#  'Slaughtering Operations (Swine) NC II' 'PV Systems Installation NC II'
#  'Food Processing NC II' 'Motorcycle/Small Engine Servicing NC II'
#  'Animal Production (Ruminants) NC II'
#  'Beauty Care (Nail Care) Services NC II'
#  'Automotive Servicing (Electrical Repair) NC II'
#  'Automotive Servicing (Engine Repair) NC II'
#  'Construction Painting NC II' 'Gas Metal Arc Welding (GMAW) NC III'
#  'Barangay Health Services NC II' 'Artificial Insemination (Swine) NC II'
#  'Automotive Servicing (Chassis Repair) NC II' 'Plumbing NC I'
#  'Pest Management (Vegetables) NC II' 'Commercial Cooking NC IV'
#  'Tailoring NC II' 'Electric Power Distribution Line Construction NC II'
#  'Animation NC II' 'Heavy Equipment Operation (Road Roller) NC II'
#  'Dental Hygiene NC IV'
#  'Dental Laboratory Technology Services (Removable Dentures/Appliances) NC II'
#  'Dental Laboratory Technology Services NC I' 'Machining NC II'
#  'RAC Servicing (DomRAC) NC II' 'Agroentrepreneurship NC III'
#  'Automotive Wiring Harness Assembly NC II'
#  'Instrumentation and Control Servicing NC II'
#  'Driving (Articulated Vehicle) NC III'
#  'Dental Laboratory Technology Services (Fixed Dentures/Restorations) NC II'
#  'Barbering NC II' 'Pharmacy Services NC III'
#  'Gas Metal Arc Welding (GMAW) NC II' 'Mechatronics Servicing NC III'
#  'Agricultural Crops Production NC III'
#  'Slaughtering Operations (Large Animal) NC II' '2D Animation NC III'
#  'Web Development NC III' 'Security Services NC I'
#  'Animal Health Care and Management NC III'
#  'Heavy Equipment Operation (Rigid On-Highway Dump Truck) NC II'
#  'Heavy Equipment Servicing (Mechanical) NC II' 'Customer Services NC II'
#  'Housekeeping NC III' 'Hairdressing NC II'
#  'Emergency Medical Services NC III' 'CNC Milling Machine Operation NC II'
#  'Food and Beverage Services NC III' 'Medical Transcription NC II'
#  'PV Systems Servicing NC III' 'Automotive Body Repairing NC II'
#  'Automotive Painting NC II' 'Illustration NC II'
#  'Caregiving (Newborn to Pre-Schooler) NC II'
#  'Biomedical Equipment Servicing NC II']

# %%
tourism_hospitality_list = [
    # Hospitality & Tourism Operations
    "Front Office Services NC II",
    "Tourism Promotion Services NC II",
    "Tour Guiding Services NC II",
    "Events Management Services NC III",
    "Contact Center Services NC II",
    "Housekeeping NC II",
    "Housekeeping NC III",
    "Security Services NC II",

    # Restaurant & Food Service Operations
    "Food and Beverage Services NC II",
    "Food and Beverage Services NC III",
    "Bartending NC II",
    "Barista NC II",
    "Cookery NC II",
    "Bread and Pastry Production NC II",
    "Commercial Cooking NC III",
    "Commercial Cooking NC IV",

    # Culinary Arts & Kitchen Management
    "Food Processing NC II",

    # Travel & Tourism Technology
    "Tour Guiding Services NC II",
    "Tourism Promotion Services NC II",
    "Front Office Services NC II",

    # Related Support Roles in Hospitality
    "Bookkeeping NC III",
    "Customer Services NC II",
    "Medical Transcription NC II",
    "Hilot (Wellness Massage) NC II"
]

# %% [markdown]
# ## Total Enrolled (E)

# %%
# Filter rows for Region VII - Central Visayas and tourism/hospitality qualifications
region_vii_cebu_tourism = df[
    (df["Region Name"] == "Region VII - Central Visayas") &
    (df["Province Name"] == "Cebu") &
    (df["Qualification"].isin(tourism_hospitality_list))
]

# Calculate total enrolled
total_enrolled = region_vii_cebu_tourism["Enrolled"].sum()

print("Total Enrolled (Tourism & Hospitality, Region VII - Central Visayas):", total_enrolled)
# Out:
# Total Enrolled (Tourism & Hospitality, Region VII - Central Visayas): 3416

# %% [markdown]
# ## Total Graduated (G)

# %%
# Calculate total graduates
total_graduates = region_vii_cebu_tourism["Graduates"].sum()

print("Total Graduates (Tourism & Hospitality, Region VII - Central Visayas):", total_graduates)
# Out:
# Total Graduates (Tourism & Hospitality, Region VII - Central Visayas): 3015

# %% [markdown]
# ### Loading Data and Qualifications

# %% [markdown]
# Getting entries under column "Qualification"

# %%
file_path2 = "data/AG 2025.csv"
df2 = pd.read_csv(file_path2, header=1)

# %%
df2.columns = df2.columns.str.strip()
df2["Qualification"] = df2["Qualification"].astype(str).str.strip()
unique_qualifications = df["Qualification"].unique()

print(unique_qualifications)
# Out:
# ['Bread and Pastry Production NC II' 'Cookery NC II'
#  'Food and Beverage Services NC II' 'Hilot (Wellness Massage) NC II'
#  'Driving NC II' 'Carpentry NC II' 'Gas Metal Arc Welding (GMAW) NC II'
#  'Heavy Equipment Operation (Forklift) NC II'
#  'Scaffolding Works (Supported Type Scaffold) NC II'
#  'Shielded Metal Arc Welding (SMAW) NC II' 'Tile Setting NC II'
#  'Driving (Passenger Bus/Straight Truck) NC III'
#  'Heavy Equipment Operation (Hydraulic Excavator) NC II'
#  'Heavy Equipment Operation (Rigid On-Highway Dump Truck) NC II'
#  'Heavy Equipment Operation (Truck Mounted Crane) NC II'
#  'Heavy Equipment Operation (Wheel Loader) NC II'
#  'Motorcycle/Small Engine Servicing NC II'
#  'Agricultural Crops Production NC II'
#  'Agricultural Crops Production NC III' 'Animal Production (Swine) NC II'
#  'Automotive Servicing NC I' 'Computer Systems Servicing NC II'
#  'Electronic Products Assembly and Servicing NC II' 'Masonry NC II'
#  'Shielded Metal Arc Welding (SMAW) NC I' 'Trainers Methodology Level I'
#  'Electrical Installation and Maintenance NC II'
#  'Organic Agriculture Production NC II' 'Caregiving NC II'
#  'Health Care Services NC II' 'Housekeeping NC II'
#  'Agricultural Crops Production NC I' 'Visual Graphic Design NC III'
#  'Front Office Services NC II' 'Agroentrepreneurship NC II'
#  'Agroentrepreneurship NC III' 'Events Management Services NC III'
#  'Food and Beverage Services NC III' 'Barista NC II' 'Dressmaking NC II'
#  'Bookkeeping NC III' 'Heavy Equipment Operation (Backhoe Loader) NC II'
#  'Bartending NC II' 'Commercial Cooking NC III' 'Food Processing NC II'
#  'Tourism Promotion Services NC II' 'Biomedical Equipment Servicing NC II'
#  'Massage Therapy NC II' 'Animal Production (Ruminants) NC II'
#  'Rice Machinery Operations NC II' 'Slaughtering Operations (Swine) NC II'
#  'Barangay Health Services NC II' 'Domestic Work NC II'
#  'PV Systems Installation NC II' 'RAC Servicing (DomRAC) NC II'
#  'Automotive Servicing (Chassis Repair) NC II'
#  'Automotive Servicing (Engine Repair) NC II'
#  'Driving (Articulated Vehicle) NC III'
#  'Shielded Metal Arc Welding (SMAW) NC III'
#  'Heavy Equipment Operation (Bulldozer) NC II'
#  'Heavy Equipment Operation (Road Roller) NC II'
#  'Heavy Equipment Operation (Transit Mixer) NC II' 'Housekeeping NC III'
#  'Automotive Servicing (Electrical Repair) NC II'
#  'Heavy Equipment Servicing (Mechanical) NC II'
#  'Construction Painting NC II' "Ship's Catering Services NC I"
#  'Gas Metal Arc Welding (GMAW) NC III' 'Pharmacy Services NC III'
#  'Beauty Care (Nail Care) Services NC II' 'Technical Drafting NC II'
#  'Aquaculture NC II' 'Animal Health Care and Management NC III'
#  'Pest Management (Vegetables) NC II'
#  'Animal Production (Poultry-Chicken) NC II'
#  'Drying and Milling Plant Servicing NC III'
#  'Electrical Installation and Maintenance NC III' 'Plumbing NC II'
#  'Security Services NC II' 'Handloom Weaving (Upright) NC II'
#  'Caregiving (Elderly) NC II' 'Tailoring NC II' 'Horticulture NC III'
#  'Rigging NC I' 'Gas Tungsten Arc Welding (GTAW) NC II' 'Masonry NC I'
#  'Gas Metal Arc Welding (GMAW) NC I' 'Grains Production NC II'
#  'Instrumentation and Control Servicing NC II'
#  'Instrumentation and Control Servicing NC III' 'Animation NC II'
#  'Pipefitting (Metallic) NC II'
#  'Heavy Equipment Operation (Crawler Crane) NC III'
#  'Heavy Equipment Operation (Overhead and Gantry Crane) NC III'
#  'Heavy Equipment Operation (Rough Terrain Crane) NC III'
#  'Heavy Equipment Operation (Truck Mounted Crane) NC III'
#  "Ships' Catering (Ships' Cooks) NC III"
#  'Landscape Installation and Maintenance (Softscape) NC II'
#  'Slaughtering Operations (Large Animal) NC II' 'Hairdressing NC II'
#  'Customer Services NC II' 'Food and Beverage Services NC IV'
#  'Web Development NC III' 'Front Office Services NC III'
#  'Front Office Services NC IV' 'Reinforcing Steel Works NC II'
#  'Housekeeping NC IV' 'Flux-Cored Arc Welding (FCAW) NC II'
#  'Emergency Medical Services NC III' 'Real Estate Services NC II'
#  'Agroentrepreneurship NC IV' 'Emergency Medical Services NC II'
#  'Automotive Wiring Harness Assembly NC II'
#  'Commercial Air-conditioning Installation and Servicing NC III'
#  'Flux-Cored Arc Welding (FCAW) NC I'
#  'Electric Power Distribution Line Construction NC II'
#  'Beauty Care (Skin Care) Services NC II' 'Mechatronics Servicing NC II'
#  'Microfinance Technology NC II' 'Machining NC I'
#  'Mechatronics Servicing NC III' 'Automotive Painting NC II'
#  'Automotive Servicing NC III' 'Automotive Servicing NC IV'
#  'Heavy Equipment Operation (Motor Grader) NC II' 'Food Processing NC I'
#  'Barbering NC II' 'Fashion Design (Apparel) NC III'
#  'PV Systems Servicing NC III' 'Local Guiding Services NC II'
#  'Plumbing NC I' 'Machining NC II' 'Medical Transcription NC II'
#  'Community Nutrition Services NC II' 'Security Services NC I'
#  'Commercial Cooking NC IV' 'System Formworks Installation NC II'
#  'Heavy Equipment Operation (Tower Crane) NC III'
#  'Heavy Equipment Operation (Rigid Off-Highway Dump Truck) NC II'
#  'Public Employment Services NC IV'
#  'Artificial Insemination (Swine) NC II' 'Photography NC II'
#  'Telecom OSP Installation (Fiber Optic Cable) NC II'
#  'Bamboo Production NC II' 'Rubber Production NC II' 'Fish Capture NC II'
#  'Bamboo Processing (Engineered Bamboo) NC II' '2D Animation NC III'
#  'Carpentry NC III' 'Masonry NC III' 'Travel Services NC II'
#  '3D Animation NC III' 'Trainers Methodology Level II'
#  'Mobile Phones and Handheld Gadgets Servicing NC III'
#  'Heavy Equipment Operation (Crawler Crane) NC II'
#  'Heavy Equipment Operation (Gantry Crane) NC II'
#  'Heavy Equipment Operation (Rough Terrain Crane) NC II'
#  'Heavy Equipment Operation (Tower Crane) NC II'
#  'Dental Laboratory Technology Services (Fixed Dentures/Restorations) NC II'
#  'Illustration NC II' 'CNC Lathe Machine Operation NC II'
#  'CNC Milling Machine Operation NC II'
#  'Beauty Care Services (Nail Care) NC II' 'Seaweed Production NC II' 'nan']

# %%
# Define tourism qualifications
tourism_list = [
    "Tour Guiding Services NC II",
    "Tourism Promotion Services NC II",
    "Front Office Services NC II",
    "Food and Beverage Services NC II",
    "Bartending NC II",
    "Housekeeping NC II",
    "Barista NC II",
    "Cookery NC II",
    "Bread and Pastry Production NC II",
    "Commercial Cooking NC III",
    "Commercial Cooking NC IV",
    "Events Management Services NC III",
    "Travel Services NC II"
]

# %% [markdown]
# ## Total Assessed (A)

# %%
# Clean up spaces and hidden characters
df2.columns = df2.columns.str.strip().str.replace('\ufeff', '', regex=True)
df2["Region"] = df2["Region"].astype(str).str.strip()
df2["Qualification"] = df2["Qualification"].astype(str).str.strip()

region_vii_cebu_tourism = df2[
    (df2["Region"] == "Region VII - Central Visayas") &
    (df2["Province"] == "Cebu") &
    (df2["Qualification"].isin(tourism_list))
]

# Calculate total assessed
total_assessed = region_vii_cebu_tourism["Assessed"].sum()
print("Total Assessed (Tourism, Region VII - Central Visayas):", total_assessed)
# Out:
# Total Assessed (Tourism, Region VII - Central Visayas): 5140.0

# %% [markdown]
# ## Total Certified (C)

# %%
# Calculate total certified
total_certified = region_vii_cebu_tourism["Certified"].sum()

print("Total Certified (Tourism, Region VII - Central Visayas):", total_certified)
# Out:
# Total Certified (Tourism, Region VII - Central Visayas): 5057.0
