# %%
import pandas as pd
from huggingface_hub import snapshot_download

# %% [markdown]
# # Download the files

# %%
snapshot_download(
    repo_id="Anthropic/EconomicIndex",
    repo_type="dataset",
    allow_patterns="release_2025_02_10/*",
    local_dir="../data/anthropic_index",
)

snapshot_download(
    repo_id="Anthropic/EconomicIndex",
    repo_type="dataset",
    allow_patterns="release_2025_03_27/*",
    local_dir="../data/anthropic_index",
)

snapshot_download(
    repo_id="Anthropic/EconomicIndex",
    repo_type="dataset",
    allow_patterns="release_2025_09_15/*",
    local_dir="../data/anthropic_index",
)

snapshot_download(
    repo_id="Anthropic/EconomicIndex",
    repo_type="dataset",
    allow_patterns="release_2026_01_15/*",
    local_dir="../data/anthropic_index",
)

snapshot_download(
    repo_id="Anthropic/EconomicIndex",
    repo_type="dataset",
    allow_patterns="release_2026_03_24/*",
    local_dir="../data/anthropic_index",
)

snapshot_download(
    repo_id="Anthropic/EconomicIndex",
    repo_type="dataset",
    allow_patterns="release_2026_06_26/*",
    local_dir="../data/anthropic_index",
)
# Out:
# ...
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# '/Users/jfv/Desktop/wadhwani/10_AI_research/data/anthropic_index'
