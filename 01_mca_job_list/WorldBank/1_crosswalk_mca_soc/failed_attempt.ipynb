# %%
import pandas as pd
import numpy as np
import re
from thefuzz import fuzz, process
from thefuzz import process
from typing import Optional, Union, Literal, Iterable, Any, Dict, Tuple

# %% [markdown]
# # Get Possible Names of Each Job to ISCO Code

# %% [markdown]
# We’ll load the PSOC Excel file and focus only on two columns: Job Title and ISCO code. The ISCO code will serve as the key to link PSOC with O*NET, where we can attach the AIOE and Complementarity scores. We also have to note that The PSA lists job titles in a clear cycle. Each section starts with the main job title in all caps, followed by a description of tasks. It then introduces related titles with the phrase “Examples of the occupations classified here:”. The cycle repeats with a new ISCO code whenever a new all-caps job title appears. We will utilize this to get a one to many mapping of the ISCO code to the job title.

# %%
def add_job_isco(df_map: pd.DataFrame, job_isco: Dict[str, int]) -> Dict[str, int]:
    """
    Build a mapping of job titles (main + examples) to their ISCO codes.

    Parameters
    ----------
    df_map : pd.DataFrame
        DataFrame with columns ["Job Title", "ISCO"].
    job_isco : dict
        Dictionary to update with mappings {job_title: isco_code}.

    Returns
    -------
    dict
        Updated mapping {job_title: isco_code}.
    """
    collecting: bool = False

    phrase_1 = "Some related occupations classified elsewhere:"
    phrase_2 = "Related occupation classified elsewhere:"

    for _, row in df_map.iterrows():
        title: str = row["Job Title"]
        code = row["ISCO"]

        # If all caps job title is seen, collect it 
        # but also know that the tasks should not be collected
        if title.isupper():
            # Main job title
            job_isco[title] = code
            collecting = False

        # Start collecting example job titles
        elif "Examples of the occupations classified here:" in title:
            collecting = True
        
        # If this phrase is seen, stop collecting
        elif (phrase_1 in title) or (phrase_2 in title):
            collecting = False

        # Collect this specific job title
        elif collecting:
            job_isco[title] = code

    return job_isco

# %%
# Get the data
filename = '2022-Updates-to-the-2012-PSOC.xlsx'
relevant_cols = [3, 5]
names = ['Job Title', 'ISCO']
df_maps = pd.read_excel(
    filename, 
    usecols=relevant_cols, 
    names=names,
    sheet_name=None,
    dtype={"Job Title": str, "ISCO": str}
    )

# %%
# for each df_map in df_maps, get their jobs to ISCO pairs
job_isco = {}

for _, df_map in df_maps.items():
    # Replace empty strings or strings with only whitespace with NaN
    df_map["ISCO"] = df_map["ISCO"].replace(r"^\s*$", np.nan, regex=True)
    
    # Forward fill ISCO codes
    df_map["ISCO"].ffill(inplace=True)

    # Extract only first 4 digits
    df_map["ISCO"] = df_map["ISCO"].astype(str).str.extract(r"(\d{4})")[0]

    
    # Drop rows missing job title (but keep NaN ISCO for now)
    df_map.dropna(inplace=True)

    # Drop duplicate job titles
    df_map.drop_duplicates(inplace=True, ignore_index=True)

    add_job_isco(df_map, job_isco)

# %%
mapping = pd.DataFrame(list(job_isco.items()), columns=names)
# Get the Major Group
mapping['Group'] = mapping['ISCO'].astype(str).str[0].astype(int)
mapping.head()
# Out:
#                                            Job Title  ISCO  Group
# 0                                        LEGISLATORS  1111      1
# 1                           City/Municipal Councilor  1111      1
# 2                                        Congressman  1111      1
# 3  Member of the Barangay Council (Sangguniang Pa...  1111      1
# 4  Member of the Provincial Board (Sangguniang Pa...  1111      1

# %% [markdown]
# # Map each job in MCA to the closest ISCO code based on Job Title

# %% [markdown]
# Each job in the MCA dataset will be mapped to the closest ISCO code by comparing its job title to the list of PSOC job titles using fuzzy string matching with the ```fuzzywuzzy``` library, which scores similarity based on character-level differences and selects the best match.

# %%
filename = 'FINAL (WIP)-MCA Job list August 2025(USE_final).csv'
mca_df = pd.read_csv(filename, encoding='latin1')

# Remove the trailing white space and lower case
mca_df['Job Sector'] = mca_df['Job Sector'].str.strip().str.lower()
mca_df['Job Title'] = mca_df['Job Title'].str.strip()

mca_df.head()
# Out:
#                         Job Title                               Job Sector  \
# 0  2D Echocardiography Technician  human health and social work activities
# 1                  2D Game Artist       arts, entertainment and recreation
# 2                  3D Game Artist       arts, entertainment and recreation
# 3                     3D Modeller       arts, entertainment and recreation
# 4            3D Printing Designer                            manufacturing
#
#                                        Job Subsector   Educational Pathway  \
# 0             Medical and dental practice activities      Higher Education
# 1        Creative, arts and entertainment activities  Not Higher Education
# 2        Creative, arts and entertainment activities  Not Higher Education
# 3        Creative, arts and entertainment activities  Not Higher Education
# 4  Manufacture of other fabricated metal products...      Higher Education
#
#   HEI with PRC (Professional Regulation Commission) Exam Some HEI
# 0                                                 No          Yes
# 1                                                 No           No
# 2                                                 No           No
# 3                                                 No           No
# 4                                                 No           No

# %%
jobs_to_keep = ['Cold Storage Technician',
 'Commercial Diver',
 'Dental Laboratory Technician',
 'Digital Background Painting',
 'EV Battery Automotive Mechanic',
 'Food Safety Auditor',
 'HACCP Coordinator',
 'Junior Airline Accounting Clerk',
 'Maintenance Laborer',
 'Milk Processing Technician',
 'Product Development Technician',
 'R&D Food Specialist',
 'Semiconductor Operator',
 'Wastewater Treatment Specialist',
 'Water Quality Engineer']

filtered_df = mca_df[mca_df["Job Title"].isin(jobs_to_keep)]
filtered_df
# Out:
#                             Job Title  \
# 190           Cold Storage Technician
# 192                  Commercial Diver
# 289      Dental Laboratory Technician
# 298       Digital Background Painting
# 376    EV Battery Automotive Mechanic
# 434               Food Safety Auditor
# 478                 HACCP Coordinator
# 570   Junior Airline Accounting Clerk
# 680               Maintenance Laborer
# 738        Milk Processing Technician
# 866    Product Development Technician
# 906               R&D Food Specialist
# 981            Semiconductor Operator
# 1131  Wastewater Treatment Specialist
# 1133           Water Quality Engineer
#
#                                              Job Sector  \
# 190                                       manufacturing
# 192                          transportation and storage
# 289             human health and social work activities
# 298                       information and communication
# 376                                       manufacturing
# 434                                       manufacturing
# 478                                       manufacturing
# 570                          transportation and storage
# 680                                        construction
# 738                                       manufacturing
# 866                                       manufacturing
# 906                                       manufacturing
# 981                                       manufacturing
# 1131  water supply; sewerage, waste management and r...
# 1133  water supply; sewerage, waste management and r...
#
#                                           Job Subsector   Educational Pathway  \
# 190   Installation of industrial machinery and equip...      Higher Education
# 192   Sea and coastal water transport, Inland water ...  Not Higher Education
# 289              Medical and dental practice activities  Not Higher Education
# 298   Motion picture, video and television programme...      Higher Education
# 376           Manufacture of batteries and accumulators  Not Higher Education
# 434                  Manufacture of other food products      Higher Education
# 478                  Manufacture of other food products      Higher Education
# 570      Passenger air transport, Freight air transport      Higher Education
# 680                           Construction of buildings  Not Higher Education
# 738                       Manufacture of dairy products      Higher Education
# 866                  Manufacture of other food products      Higher Education
# 906                  Manufacture of other food products      Higher Education
# 981                Manufacture of electronic components  Not Higher Education
# 1131                       Waste treatment and disposal      Higher Education
# 1133             Water collection, treatment and supply      Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI
# 190                                                  No           No
# 192                                                  No           No
# 289                                                  No           No
# 298                                                  No           No
# 376                                                  No           No
# 434                                                 Yes           No
# 478                                                  No           No
# 570                                                 Yes           No
# 680                                                  No           No
# 738                                                  No           No
# 866                                                 Yes           No
# 906                                                 Yes           No
# 981                                                  No           No
# 1131                                                Yes           No
# 1133                                                Yes           No

# %%
sector_to_major_group = {
    "human health and social work activities": [2, 3, 5],
    "arts, entertainment and recreation": [2, 3, 5],
    "manufacturing": [7, 8],
    "agriculture, forestry, and fishing": [6, 9],
    "professional, scientific and technical activities": [2, 3],
    "construction": [7, 9],
    "financial and insurance activities": [1, 2, 4],
    "administrative and support service activities": [4, 5],
    "other service activities": [4, 5],
    "information and communication": [2, 3, 4],
    "transportation and storage": [8, 9],
    "education": [2, 3],
    "accommodation and food service activities": [5],
    "wholesale and retail trade; repair of motor vehicles and motorcycles": [5, 9],
    "public administration and defense; compulsory social security": [1, 2, 3],
    "electricity, gas, steam and air conditioning supply": [7, 8],
    "water supply; sewerage, waste management and remediation": [7, 8],
    "real estate activities": [1, 2, 4],
    "mining and quarrying": [7, 8, 9],
    "armed forces": [0]
}

# %%
def map_to_isco(mca_title: str, job_isco: Dict[str, int]) -> Tuple[str, int, int]:
    """
    Map an MCA job title to the closest PSOC job title and return its ISCO code.

    Args:
        mca_title (str): The MCA job title to map.
        job_isco (Dict[str, int]): Dictionary of PSOC job titles to ISCO codes.

    Returns:
        Tuple[str, int, int]: Best matching PSOC job title, its ISCO code, and similarity score.
    """
    psoc_titles = list(job_isco.keys())
    best_match, score = process.extractOne(mca_title, psoc_titles)
    isco_code = job_isco[best_match]
    return best_match, isco_code, score

# %%
# Prepare new columns
mca_df['Best Match'] = ""
mca_df['ISCO Code'] = 0
mca_df['Similarity Score'] = 0

for idx, job in mca_df.iterrows():
    title, sector = job['Job Title'], job['Job Sector']
    groups = sector_to_major_group[sector]

    # Filter mapping by allowed Major Groups
    filt = mapping['Group'].isin(groups)
    filtered = mapping[filt][['Job Title', 'ISCO']]

    # Create filtered dictionary
    filt_job_to_isco = dict(zip(filtered['Job Title'], filtered['ISCO']))

    # Map MCA job title to closest PSOC title
    if filt_job_to_isco:  # only if there are filtered titles
        best_match, isco_code, score = map_to_isco(title, filt_job_to_isco)
    else:
        best_match, isco_code, score = None, None, 0  # fallback if no titles

    # Assign to new columns
    mca_df.at[idx, 'Best Match'] = best_match
    mca_df.at[idx, 'ISCO Code'] = isco_code
    mca_df.at[idx, 'Similarity Score'] = score
# Out:
# /var/folders/80/nt46s_zj37q09s9bvd_1j0vw0000gn/T/ipykernel_45478/2493998309.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2166' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   mca_df.at[idx, 'ISCO Code'] = isco_code

# %%
mca_df
# Out:
#                            Job Title  \
# 0     2D Echocardiography Technician
# 1                     2D Game Artist
# 2                     3D Game Artist
# 3                        3D Modeller
# 4               3D Printing Designer
# ...                              ...
# 1146                  Window Cleaner
# 1147                     Wood Carver
# 1148    Workforce Management Analyst
# 1149  Workforce Wellness Coordinator
# 1150                Worship Musician
#
#                                          Job Sector  \
# 0           human health and social work activities
# 1                arts, entertainment and recreation
# 2                arts, entertainment and recreation
# 3                arts, entertainment and recreation
# 4                                     manufacturing
# ...                                             ...
# 1146      accommodation and food service activities
# 1147                                  manufacturing
# 1148  administrative and support service activities
# 1149        human health and social work activities
# 1150             arts, entertainment and recreation
#
#                                           Job Subsector   Educational Pathway  \
# 0                Medical and dental practice activities      Higher Education
# 1           Creative, arts and entertainment activities  Not Higher Education
# 2           Creative, arts and entertainment activities  Not Higher Education
# 3           Creative, arts and entertainment activities  Not Higher Education
# 4     Manufacture of other fabricated metal products...      Higher Education
# ...                                                 ...                   ...
# 1146                                Other accommodation      Higher Education
# 1147                           Manufacture of furniture  Not Higher Education
# 1148        Business support service activities, n.e.c.      Higher Education
# 1149  Other social work activities without accommoda...      Higher Education
# 1150        Creative, arts and entertainment activities      Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI  \
# 0                                                    No          Yes
# 1                                                    No           No
# 2                                                    No           No
# 3                                                    No           No
# 4                                                    No           No
# ...                                                 ...          ...
# 1146                                                 No           No
# 1147                                                 No           No
# 1148                                                 No           No
# 1149                                                 No          Yes
# 1150                                                 No           No
#
#                            Best Match ISCO Code  Similarity Score
# 0                        2D animators      2166                86
# 1             Website game developers      2513                86
# 2             Website game developers      2513                86
# 3                  Financial modelers      2413                72
# 4     HANDICRAFT AND PRINTING WORKERS      7234                86
# ...                               ...       ...               ...
# 1146                   Dorm caretaker      5153                57
# 1147                      Wood carver      7317               100
# 1148                          Fireman      5411                64
# 1149               Events coordinator      3332                86
# 1150                         Musician      2652                90
#
# [1151 rows x 9 columns]

# %%
jobs_to_keep = ['Cold Storage Technician',
 'Commercial Diver',
 'Dental Laboratory Technician',
 'Digital Background Painting',
 'EV Battery Automotive Mechanic',
 'Food Safety Auditor',
 'HACCP Coordinator',
 'Junior Airline Accounting Clerk',
 'Maintenance Laborer',
 'Milk Processing Technician',
 'Product Development Technician',
 'R&D Food Specialist',
 'Semiconductor Operator',
 'Wastewater Treatment Specialist',
 'Water Quality Engineer']

filtered_df = mca_df[mca_df["Job Title"].isin(jobs_to_keep)]
filtered_df
# Out:
#                             Job Title  \
# 190           Cold Storage Technician
# 192                  Commercial Diver
# 289      Dental Laboratory Technician
# 298       Digital Background Painting
# 376    EV Battery Automotive Mechanic
# 434               Food Safety Auditor
# 478                 HACCP Coordinator
# 570   Junior Airline Accounting Clerk
# 680               Maintenance Laborer
# 738        Milk Processing Technician
# 866    Product Development Technician
# 906               R&D Food Specialist
# 981            Semiconductor Operator
# 1131  Wastewater Treatment Specialist
# 1133           Water Quality Engineer
#
#                                              Job Sector  \
# 190                                       manufacturing
# 192                          transportation and storage
# 289             human health and social work activities
# 298                       information and communication
# 376                                       manufacturing
# 434                                       manufacturing
# 478                                       manufacturing
# 570                          transportation and storage
# 680                                        construction
# 738                                       manufacturing
# 866                                       manufacturing
# 906                                       manufacturing
# 981                                       manufacturing
# 1131  water supply; sewerage, waste management and r...
# 1133  water supply; sewerage, waste management and r...
#
#                                           Job Subsector   Educational Pathway  \
# 190   Installation of industrial machinery and equip...      Higher Education
# 192   Sea and coastal water transport, Inland water ...  Not Higher Education
# 289              Medical and dental practice activities  Not Higher Education
# 298   Motion picture, video and television programme...      Higher Education
# 376           Manufacture of batteries and accumulators  Not Higher Education
# 434                  Manufacture of other food products      Higher Education
# 478                  Manufacture of other food products      Higher Education
# 570      Passenger air transport, Freight air transport      Higher Education
# 680                           Construction of buildings  Not Higher Education
# 738                       Manufacture of dairy products      Higher Education
# 866                  Manufacture of other food products      Higher Education
# 906                  Manufacture of other food products      Higher Education
# 981                Manufacture of electronic components  Not Higher Education
# 1131                       Waste treatment and disposal      Higher Education
# 1133             Water collection, treatment and supply      Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI  \
# 190                                                  No           No
# 192                                                  No           No
# 289                                                  No           No
# 298                                                  No           No
# 376                                                  No           No
# 434                                                 Yes           No
# 478                                                  No           No
# 570                                                 Yes           No
# 680                                                  No           No
# 738                                                  No           No
# 866                                                 Yes           No
# 906                                                 Yes           No
# 981                                                  No           No
# 1131                                                Yes           No
# 1133                                                Yes           No
#
#                                              Best Match ISCO Code  \
# 190        Automotive brakes systems service technician      7231
# 192                                         Bus driver       8331
# 289                       Medical laboratory technician      3212
# 298                                      Digital artist      2166
# 376                                 Automotive mechanic      7231
# 434   FOOD PROCESSING, WOOD WORKING, GARMENT AND OTH...      7422
# 478                                              Cooper      7522
# 570                                      Mining driller      8111
# 680                            Dams maintenance laborer      9312
# 738                                    Drain technician      7126
# 866                                    Drain technician      7126
# 906   FOOD PROCESSING, WOOD WORKING, GARMENT AND OTH...      7422
# 981      Metal working drilling machine setter-operator      7223
# 1131                                             Hatter      7531
# 1133            Aircraft airframes maintenance engineer      7232
#
#       Similarity Score
# 190                 86
# 192                 68
# 289                 88
# 298                 86
# 376                 90
# 434                 86
# 478                 68
# 570                 58
# 680                 95
# 738                 86
# 866                 86
# 906                 86
# 981                 86
# 1131                68
# 1133                86

# %%
fil

# %%
mca_df[mca_df['Job Title'] == 'Water Quality Engineer']
# Out:
#                    Job Title  \
# 1133  Water Quality Engineer
#
#                                              Job Sector  \
# 1133  water supply; sewerage, waste management and r...
#
#                                Job Subsector Educational Pathway  \
# 1133  Water collection, treatment and supply    Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI  \
# 1133                                                Yes           No
#
#                                    Best Match ISCO Code  Similarity Score
# 1133  Aircraft airframes maintenance engineer      7232                86

# %%
filtered_df
# Out:
#                             Job Title  \
# 190           Cold Storage Technician
# 192                  Commercial Diver
# 289      Dental Laboratory Technician
# 298       Digital Background Painting
# 376    EV Battery Automotive Mechanic
# 434               Food Safety Auditor
# 478                 HACCP Coordinator
# 570   Junior Airline Accounting Clerk
# 680               Maintenance Laborer
# 738        Milk Processing Technician
# 866    Product Development Technician
# 906               R&D Food Specialist
# 981            Semiconductor Operator
# 1131  Wastewater Treatment Specialist
# 1133           Water Quality Engineer
#
#                                              Job Sector  \
# 190                                       manufacturing
# 192                          transportation and storage
# 289             human health and social work activities
# 298                       information and communication
# 376                                       manufacturing
# 434                                       manufacturing
# 478                                       manufacturing
# 570                          transportation and storage
# 680                                        construction
# 738                                       manufacturing
# 866                                       manufacturing
# 906                                       manufacturing
# 981                                       manufacturing
# 1131  water supply; sewerage, waste management and r...
# 1133  water supply; sewerage, waste management and r...
#
#                                           Job Subsector   Educational Pathway  \
# 190   Installation of industrial machinery and equip...      Higher Education
# 192   Sea and coastal water transport, Inland water ...  Not Higher Education
# 289              Medical and dental practice activities  Not Higher Education
# 298   Motion picture, video and television programme...      Higher Education
# 376           Manufacture of batteries and accumulators  Not Higher Education
# 434                  Manufacture of other food products      Higher Education
# 478                  Manufacture of other food products      Higher Education
# 570      Passenger air transport, Freight air transport      Higher Education
# 680                           Construction of buildings  Not Higher Education
# 738                       Manufacture of dairy products      Higher Education
# 866                  Manufacture of other food products      Higher Education
# 906                  Manufacture of other food products      Higher Education
# 981                Manufacture of electronic components  Not Higher Education
# 1131                       Waste treatment and disposal      Higher Education
# 1133             Water collection, treatment and supply      Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI  \
# 190                                                  No           No
# 192                                                  No           No
# 289                                                  No           No
# 298                                                  No           No
# 376                                                  No           No
# 434                                                 Yes           No
# 478                                                  No           No
# 570                                                 Yes           No
# 680                                                  No           No
# 738                                                  No           No
# 866                                                 Yes           No
# 906                                                 Yes           No
# 981                                                  No           No
# 1131                                                Yes           No
# 1133                                                Yes           No
#
#                                              Best Match ISCO Code  \
# 190        Automotive brakes systems service technician      7231
# 192                                         Bus driver       8331
# 289                       Medical laboratory technician      3212
# 298                                      Digital artist      2166
# 376                                 Automotive mechanic      7231
# 434   FOOD PROCESSING, WOOD WORKING, GARMENT AND OTH...      7422
# 478                                              Cooper      7522
# 570                                      Mining driller      8111
# 680                            Dams maintenance laborer      9312
# 738                                    Drain technician      7126
# 866                                    Drain technician      7126
# 906   FOOD PROCESSING, WOOD WORKING, GARMENT AND OTH...      7422
# 981      Metal working drilling machine setter-operator      7223
# 1131                                             Hatter      7531
# 1133            Aircraft airframes maintenance engineer      7232
#
#       Similarity Score
# 190                 86
# 192                 68
# 289                 88
# 298                 86
# 376                 90
# 434                 86
# 478                 68
# 570                 58
# 680                 95
# 738                 86
# 866                 86
# 906                 86
# 981                 86
# 1131                68
# 1133                86

# %%
mca_df
# Out:
#                            Job Title  \
# 0     2D Echocardiography Technician
# 1                     2D Game Artist
# 2                     3D Game Artist
# 3                        3D Modeller
# 4               3D Printing Designer
# ...                              ...
# 1146                  Window Cleaner
# 1147                     Wood Carver
# 1148    Workforce Management Analyst
# 1149  Workforce Wellness Coordinator
# 1150                Worship Musician
#
#                                          Job Sector  \
# 0           human health and social work activities
# 1                arts, entertainment and recreation
# 2                arts, entertainment and recreation
# 3                arts, entertainment and recreation
# 4                                     manufacturing
# ...                                             ...
# 1146      accommodation and food service activities
# 1147                                  manufacturing
# 1148  administrative and support service activities
# 1149        human health and social work activities
# 1150             arts, entertainment and recreation
#
#                                           Job Subsector   Educational Pathway  \
# 0                Medical and dental practice activities      Higher Education
# 1           Creative, arts and entertainment activities  Not Higher Education
# 2           Creative, arts and entertainment activities  Not Higher Education
# 3           Creative, arts and entertainment activities  Not Higher Education
# 4     Manufacture of other fabricated metal products...      Higher Education
# ...                                                 ...                   ...
# 1146                                Other accommodation      Higher Education
# 1147                           Manufacture of furniture  Not Higher Education
# 1148        Business support service activities, n.e.c.      Higher Education
# 1149  Other social work activities without accommoda...      Higher Education
# 1150        Creative, arts and entertainment activities      Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI  \
# 0                                                    No          Yes
# 1                                                    No           No
# 2                                                    No           No
# 3                                                    No           No
# 4                                                    No           No
# ...                                                 ...          ...
# 1146                                                 No           No
# 1147                                                 No           No
# 1148                                                 No           No
# 1149                                                 No          Yes
# 1150                                                 No           No
#
#                            Best Match ISCO Code  Similarity Score
# 0                        2D animators      2166                86
# 1             Website game developers      2513                86
# 2             Website game developers      2513                86
# 3                  Financial modelers      2413                72
# 4     HANDICRAFT AND PRINTING WORKERS      7234                86
# ...                               ...       ...               ...
# 1146                   Dorm caretaker      5153                57
# 1147                      Wood carver      7317               100
# 1148                          Fireman      5411                64
# 1149               Events coordinator      3332                86
# 1150                         Musician      2652                90
#
# [1151 rows x 9 columns]
