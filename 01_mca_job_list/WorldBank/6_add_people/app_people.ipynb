# %%
import pandas as pd

# %%
file_name = '../final_mca_aioe_comple.csv'
pd.read_csv(file_name)
# Out:
#                            Job Title  \
# 0     2D Echocardiography Technician
# 1                     2D Game Artist
# 2                     3D Game Artist
# 3                        3D Modeller
# 4               3D Printing Designer
# ...                              ...
# 1146                  Window Cleaner
# 1147                     Wood Carver
# 1148    Workforce Management Analyst
# 1149  Workforce Wellness Coordinator
# 1150                Worship Musician
#
#                                          Job Sector  \
# 0           Human Health and Social Work Activities
# 1                Arts, Entertainment and Recreation
# 2                Arts, Entertainment and Recreation
# 3                Arts, Entertainment and Recreation
# 4                                     Manufacturing
# ...                                             ...
# 1146      Accommodation and Food Service Activities
# 1147                                  Manufacturing
# ...

# %%
file_name = '../../EDCOM/MCA_JOBLIST_COMBINED.csv'
pd.read_csv(file_name)
# Out:
#                            Job Title  \
# 0     2D Echocardiography Technician
# 1                     2D Game Artist
# 2                     3D Game Artist
# 3                        3D Modeller
# 4               3D Printing Designer
# ...                              ...
# 1146                  Window Cleaner
# 1147                     Wood Carver
# 1148    Workforce Management Analyst
# 1149  Workforce Wellness Coordinator
# 1150                Worship Musician
#
#                                              Job Sector  \
# 0               Human Health and Social Work Activities
# 1                    Arts, entertainment and recreation
# 2                    Arts, entertainment and recreation
# 3                    Arts, entertainment and recreation
# 4     Manufacturing                                 ...
# ...                                                 ...
# 1146          Accommodation and Food Service Activities
# 1147  Manufacturing                                 ...
# ...
