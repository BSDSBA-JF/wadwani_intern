# %%
import pandas as pd

# %%
file_name = '../3_soc_comple/soc_comple.csv'
pd.read_csv(file_name)
# Out:
#                            Job Title  \
# 0     2D Echocardiography Technician
# 1                     2D Game Artist
# 2                     3D Game Artist
# 3                        3D Modeller
# 4               3D Printing Designer
# ...                              ...
# 1124                  Window Cleaner
# 1125                     Wood Carver
# 1126    Workforce Management Analyst
# 1127  Workforce Wellness Coordinator
# 1128                Worship Musician
#
#                                          Job Sector  \
# 0           Human Health and Social Work Activities
# 1                Arts, Entertainment and Recreation
# 2                Arts, Entertainment and Recreation
# 3                Arts, Entertainment and Recreation
# 4                                     Manufacturing
# ...                                             ...
# 1124      Accommodation and Food Service Activities
# 1125                                  Manufacturing
# ...

# %%
file_name = '../../EDCOM/prc_passing_rates_full_with_additions.csv'
pd.read_csv(file_name)
# Out:
#                                    job_sector  year  passers  examinees  \
# 0                                 Accountancy  2025     3156       9533
# 1                                 Agriculture  2024     3628       7144
# 2                                Architecture  2025     1352       2075
# 3                        Chemical Engineering  2025      602        799
# 4                                   Chemistry  2024      592       1088
# 5                           Civil Engineering  2025     4940      16913
# 6                                 Criminology  2025    13074      25410
# 7                             Customs Brokers  2024     1265       2871
# 8                                   Dentistry  2025      764        969
# 9                             Dental Medicine  2025      764        969
# 10                     Electrical Engineering  2025     6615      11718
# 11                    Electronics Engineering  2025     1280       2820
# ...
