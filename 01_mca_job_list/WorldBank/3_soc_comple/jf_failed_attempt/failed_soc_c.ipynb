# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # a. Work Context From O*NET 21.0 Data Dictionary
#
# [O*NET 21.0 Data Dictionary](https://www.onetonline.org/find/descriptor/browse/4.C/4.C.1/4.C.1.a/4.C.1.a.2/4.C.1.d/4.C.1.c/4.C.1.b/4.C.1.b.1/4.C.2/4.C.2.d/4.C.2.d.1/4.C.2.b/4.C.2.b.1/4.C.2.c/4.C.2.c.1/4.C.2.e/4.C.2.e.1/4.C.2.a/4.C.2.a.1/4.C.3/4.C.3.c/4.C.3.a/4.C.3.a.2/4.C.3.d/4.C.3.b)

# %%
# Open up the file for the work context
filename = 'Work Context.xlsx'
work_context_df = pd.read_excel(filename)

# Get the SOC Code
work_context_df['SOC'] = work_context_df['O*NET-SOC Code'].apply(lambda x : x[:7])

# Multiply the value by 20 to make the scale from0 to 100
work_context_df['Data Value'] = work_context_df['Data Value'] * 20 

work_context_df.head(2)
# Out:
#   O*NET-SOC Code             Title   Element ID     Element Name Scale ID  \
# 0     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking       CX
# 1     11-1011.00  Chief Executives  4.C.1.a.2.c  Public Speaking      CXP
#
#                  Scale Name  Category  Data Value     N  Standard Error  \
# 0                   Context       NaN        67.8  25.0            0.22
# 1  Context (Categories 1-5)       1.0       120.4  25.0            5.14
#
#    Lower CI Bound  Upper CI Bound Recommend Suppress  Not Relevant     Date  \
# 0            2.93            3.86                  N           NaN  07/2014
# 1            0.97           29.49                  N           NaN  07/2014
#
#   Domain Source      SOC
# 0     Incumbent  11-1011
# 1     Incumbent  11-1011

# %% [markdown]
# # b. Work Context from the O*NET 24.2 Data Dictionary
#
# [O*NET 24.2 Data Dictionary](https://www.onetcenter.org/dictionary/24.2/excel/work_context.html)

# %%
# Filter for the relevant work contexts and scale (the one from 1 to 5)
relevant_contexts = [
    "Face-to-Face Discussions",
    "Public Speaking",
    "Responsibility for Outcomes and Results",
    "Responsible for Others' Health and Safety",
    "Outdoors, Exposed to Weather",
    "Physical Proximity",
    "Consequence of Error",
    "Freedom to Make Decisions",
    "Frequency of Decision Making",
    "Degree of Automation",
    "Structured versus Unstructured Work"
]

is_relevant = (
    work_context_df['Element Name'].isin(relevant_contexts)
    & (work_context_df['Scale ID'] == 'CX')
)
work_context_df = work_context_df[is_relevant]

# Keep the latest date for each SOC and ability, but preserve first-seen order
work_context_df = (
    work_context_df
    .sort_values(by='Date')
    .drop_duplicates(
        subset=['O*NET-SOC Code', 'Element Name'],
        keep='last'
    )
    .sort_index()
)

# %%
work_context_df.head()
# Out:
#    O*NET-SOC Code             Title   Element ID  \
# 0      11-1011.00  Chief Executives  4.C.1.a.2.c
# 24     11-1011.00  Chief Executives  4.C.1.a.2.l
# 54     11-1011.00  Chief Executives    4.C.1.c.1
# 60     11-1011.00  Chief Executives    4.C.1.c.2
# 96     11-1011.00  Chief Executives  4.C.2.a.1.c
#
#                                  Element Name Scale ID Scale Name  Category  \
# 0                             Public Speaking       CX    Context       NaN
# 24                   Face-to-Face Discussions       CX    Context       NaN
# 54  Responsible for Others' Health and Safety       CX    Context       NaN
# 60    Responsibility for Outcomes and Results       CX    Context       NaN
# 96               Outdoors, Exposed to Weather       CX    Context       NaN
#
#     Data Value     N  Standard Error  Lower CI Bound  Upper CI Bound  \
# 0         67.8  25.0            0.22            2.93            3.86
# 24        99.6  25.0            0.01            4.95            5.00
# 54        76.0  25.0            0.31            3.16            4.43
# 60        89.0  25.0            0.18            4.08            4.82
# 96        44.2  25.0            0.32            1.54            2.87
#
#    Recommend Suppress  Not Relevant     Date Domain Source      SOC
# 0                   N           NaN  07/2014     Incumbent  11-1011
# 24                  N           NaN  07/2014     Incumbent  11-1011
# 54                  N           NaN  07/2014     Incumbent  11-1011
# 60                  N           NaN  07/2014     Incumbent  11-1011
# 96                  N           NaN  07/2014     Incumbent  11-1011

# %% [markdown]
# # c. Job Zones

# %%
work_context_df[work_context_df['SOC'] == '27-1011']
# Out:
#        O*NET-SOC Code          Title   Element ID  \
# 101522     27-1011.00  Art Directors  4.C.1.a.2.c
# 101546     27-1011.00  Art Directors  4.C.1.a.2.l
# 101576     27-1011.00  Art Directors    4.C.1.c.1
# 101582     27-1011.00  Art Directors    4.C.1.c.2
# 101618     27-1011.00  Art Directors  4.C.2.a.1.c
# 101642     27-1011.00  Art Directors    4.C.2.a.3
# 101786     27-1011.00  Art Directors    4.C.3.a.1
# 101798     27-1011.00  Art Directors  4.C.3.a.2.b
# 101804     27-1011.00  Art Directors    4.C.3.a.4
# 101810     27-1011.00  Art Directors    4.C.3.b.2
# 101828     27-1011.00  Art Directors    4.C.3.b.8
#
#                                      Element Name Scale ID Scale Name  \
# 101522                            Public Speaking       CX    Context
# 101546                   Face-to-Face Discussions       CX    Context
# 101576  Responsible for Others' Health and Safety       CX    Context
# 101582    Responsibility for Outcomes and Results       CX    Context
# 101618               Outdoors, Exposed to Weather       CX    Context
# 101642                         Physical Proximity       CX    Context
# 101786                       Consequence of Error       CX    Context
# 101798               Frequency of Decision Making       CX    Context
# 101804                  Freedom to Make Decisions       CX    Context
# 101810                       Degree of Automation       CX    Context
# 101828        Structured versus Unstructured Work       CX    Context
#
#         Category  Data Value     N  Standard Error  Lower CI Bound  \
# 101522       NaN        36.0  25.0            0.21            1.37
# 101546       NaN        98.8  25.0            0.06            4.82
# 101576       NaN        48.4  27.0            0.19            2.03
# 101582       NaN        79.6  27.0            0.31            3.35
# 101618       NaN        34.6  27.0            0.12            1.48
# 101642       NaN        66.8  27.0            0.34            2.64
# 101786       NaN        59.0  27.0            0.45            2.01
# 101798       NaN        84.4  27.0            0.31            3.58
# 101804       NaN        85.6  27.0            0.22            3.83
# 101810       NaN        42.6  26.0            0.40            1.30
# 101828       NaN        88.8  27.0            0.19            4.05
#
#         Upper CI Bound Recommend Suppress  Not Relevant     Date  \
# 101522            2.24                  N           NaN  07/2012
# 101546            5.00                  N           NaN  07/2012
# 101576            2.80                  N           NaN  07/2012
# 101582            4.61                  N           NaN  07/2012
# 101618            1.98                  N           NaN  07/2012
# 101642            4.04                  N           NaN  07/2012
# 101786            3.88                  N           NaN  07/2012
# 101798            4.86                  N           NaN  07/2012
# 101804            4.73                  N           NaN  07/2012
# 101810            2.96                  N           NaN  07/2012
# 101828            4.82                  N           NaN  07/2012
#
#        Domain Source      SOC
# 101522     Incumbent  27-1011
# 101546     Incumbent  27-1011
# 101576     Incumbent  27-1011
# 101582     Incumbent  27-1011
# 101618     Incumbent  27-1011
# 101642     Incumbent  27-1011
# 101786     Incumbent  27-1011
# 101798     Incumbent  27-1011
# 101804     Incumbent  27-1011
# 101810     Incumbent  27-1011
# 101828     Incumbent  27-1011

# %% [markdown]
# # c. Combining Work Contexts and Job Zones

# %%
work_context_df['base_code'] = work_context_df['O*NET-SOC Code'].str[:7]

# For each base code and then for each work context, get the average
code_contexts_df = (
    work_context_df.groupby(['base_code', 'Element Name'], as_index=False)['Data Value']
        .mean()
)

# %%
# For each base code, get the average of the different values
code_auto_df = code_contexts_df.groupby(['base_code'])['Data Value'].mean()
code_comple_df = 1 / code_auto_df
soc_c = dict(zip(code_comple_df.index, code_comple_df.values))

# %%
filename = '../2_soc_aioe/soc_aioe.csv'
relevant_cols = [0, 1, 2, 3, 4, 5, 8, 9, 10]
mca_df = pd.read_csv(filename, usecols=relevant_cols)

# %%
mca_df['Complementarity'] = mca_df['SOC'].apply(lambda x : soc_c.get(x.strip(), np.nan))

# %%
mca_df['Complementarity'] = mca_df['Complementarity'].fillna(
    mca_df.groupby('major_minor')['Complementarity'].transform('median')
)

# %%
mca_df.sort_values(by='Complementarity', ascending=False)
# Out:
#                       Job Title  \
# 46     Apparel Pattern Designer
# 377   Fabric Quality Controller
# 1128           Worship Musician
# 966           Session Guitarist
# 745    Music Arranger Assistant
# ...                         ...
# 5      4-Wheel Tractor Mechanic
# 666          Maintenance Fitter
# 107                 Boat Fitter
# 385   Farm Equipment Fabricator
# 481    Heavy Equipment Mechanic
#
#                                              Job Sector  \
# 46    Manufacturing                                 ...
# 377   Manufacturing                                 ...
# 1128                 Arts, Entertainment and Recreation
# 966                  Arts, Entertainment and Recreation
# 745                  Arts, Entertainment and Recreation
# ...                                                 ...
# 5                    Agriculture, Forestry, and Fishing
# 666   Manufacturing                                 ...
# 107   Manufacturing                                 ...
# 385   Manufacturing                                 ...
# 481                                        Construction
#
#                                           Job Subsector   Educational Pathway  \
# 46    Manufacture of wearing apparel, except fur app...      Higher Education
# 377                       Manufacture of other textiles      Higher Education
# 1128        Creative, arts and entertainment activities      Higher Education
# 966         Creative, arts and entertainment activities      Higher Education
# 745         Creative, arts and entertainment activities      Higher Education
# ...                                                 ...                   ...
# 5     Support activities to agriculture and post-har...  Not Higher Education
# 666                         Other manufacturing, n.e.c.      Higher Education
# 107                         Building of ships and boats  Not Higher Education
# 385   Manufacture of structural metal products, tank...  Not Higher Education
# 481           Other specialized construction activities  Not Higher Education
#
#      HEI with PRC (Professional Regulation Commission) Exam Some HEI      SOC  \
# 46                                                   No           No  51-9031
# 377                                                  No           No  51-9031
# 1128                                                 No           No  27-2042
# 966                                                  No           No  27-2042
# 745                                                  No          Yes  27-2042
# ...                                                 ...          ...      ...
# 5                                                    No           No  49-9081
# 666                                                  No           No  49-9081
# 107                                                  No           No  49-9081
# 385                                                  No           No  49-9081
# 481                                                  No           No  49-9081
#
#           AIOE  major_minor  Complementarity
# 46    0.403718           51         0.422914
# 377   0.403718           51         0.422914
# 1128  0.617908           27         0.403670
# 966   0.617908           27         0.403670
# 745   0.617908           27         0.403670
# ...        ...          ...              ...
# 5     0.381996           49         0.247302
# 666   0.381996           49         0.247302
# 107   0.381996           49         0.247302
# 385   0.381996           49         0.247302
# 481   0.381996           49         0.247302
#
# [1129 rows x 10 columns]

# %%
plt.scatter(mca_df['AIOE'], mca_df['Complementarity'])

# %%
mca_df['Complementarity'].hist()
# Out:
# <Axes: >
