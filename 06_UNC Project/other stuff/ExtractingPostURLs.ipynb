# %%
import pandas as pd

df = pd.read_csv('PostsData.csv')

base_url = "https://www.facebook.com/greyhoundfreedomwall/posts/"
df["post_url"] = base_url + df["postId"].astype(str)

file_path = "post_urls.txt"   # save in current directory
df["post_url"].to_csv(file_path, index=False, header=False)

file_path
# Out:
# 'post_urls.txt'
